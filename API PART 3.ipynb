# %%
import requests
import json

# %%
url = 'https://randomuser.me/api/?results=500'

response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response_dict = response.json()
response_dict
# Out:
# {'results': [{'gender': 'female',
#    'name': {'title': 'Mademoiselle', 'first': 'Hanna', 'last': 'Renaud'},
#    'location': {'street': {'number': 316, 'name': 'Place de la Mairie'},
#     'city': 'Diegten',
#     'state': 'Jura',
#     'country': 'Switzerland',
#     'postcode': 4302,
#     'coordinates': {'latitude': '-62.9002', 'longitude': '15.7357'},
#     'timezone': {'offset': '0:00',
#      'description': 'Western Europe Time, London, Lisbon, Casablanca'}},
#    'email': 'hanna.renaud@example.com',
#    'login': {'uuid': '6d470436-3db5-4551-a35b-d3a5735c488d',
#     'username': 'silversnake298',
#     'password': 'escape',
#     'salt': 'YRuwweAn',
#     'md5': 'd260bd87df0a1c3a53586b7efd8f3f0a',
#     'sha1': '8c976573a1b0ed1b70f961ab55c9cfe3563a8d1f',
#     'sha256': '380785110f3d35d2e99754331de1a6bb1af9669a256f5fd3ddbbcfb17ebba5e1'},
#    'dob': {'date': '1980-12-31T05:02:26.800Z', 'age': 44},
#    'registered': {'date': '2008-10-17T15:19:03.441Z', 'age': 16},
# ...

# %%
response_dict.keys()
# Out:
# dict_keys(['results', 'info'])

# %%
profile_male =  []
profile_female = []
for trial in Trial1:
    if trial['gender'] == 'male':
        profile_male.append(trial)
    elif trial['gender'] == 'female':
        profile_female.append(trial)

profile_male
profile_female

# %%
male_birth = []
for male in profile_male:
    value = male['dob']
    male_birth.append(value)
male_birth
# Out:
# [{'date': '1996-03-04T19:59:11.209Z', 'age': 29},
#  {'date': '1990-07-16T19:53:17.795Z', 'age': 34},
#  {'date': '1994-12-30T19:04:19.332Z', 'age': 30},
#  {'date': '1950-06-30T18:53:22.576Z', 'age': 74},
#  {'date': '1948-03-18T03:17:23.370Z', 'age': 77},
#  {'date': '2000-03-14T22:04:05.536Z', 'age': 25},
#  {'date': '1981-09-27T12:02:52.719Z', 'age': 43},
#  {'date': '1992-09-18T01:47:23.241Z', 'age': 32},
#  {'date': '1979-05-13T18:31:09.967Z', 'age': 45},
#  {'date': '1992-08-08T09:01:45.011Z', 'age': 32},
#  {'date': '1992-10-31T23:42:05.276Z', 'age': 32},
#  {'date': '1950-07-04T05:13:30.119Z', 'age': 74},
#  {'date': '1976-10-07T07:10:19.512Z', 'age': 48},
#  {'date': '1953-08-06T09:08:19.436Z', 'age': 71},
#  {'date': '1970-02-12T02:44:40.538Z', 'age': 55},
#  {'date': '1970-02-17T15:24:12.506Z', 'age': 55},
#  {'date': '1978-12-18T21:09:52.734Z', 'age': 46},
#  {'date': '1971-09-30T23:27:24.058Z', 'age': 53},
#  {'date': '1950-11-04T21:33:50.131Z', 'age': 74},
# ...

# %%
male_birth_date = []
for male in male_birth:
    datevalue =  male['date']
    male_birth_date.append(datevalue)
male_birth_date
# Out:
# ['1996-03-04T19:59:11.209Z',
#  '1990-07-16T19:53:17.795Z',
#  '1994-12-30T19:04:19.332Z',
#  '1950-06-30T18:53:22.576Z',
#  '1948-03-18T03:17:23.370Z',
#  '2000-03-14T22:04:05.536Z',
#  '1981-09-27T12:02:52.719Z',
#  '1992-09-18T01:47:23.241Z',
#  '1979-05-13T18:31:09.967Z',
#  '1992-08-08T09:01:45.011Z',
#  '1992-10-31T23:42:05.276Z',
#  '1950-07-04T05:13:30.119Z',
#  '1976-10-07T07:10:19.512Z',
#  '1953-08-06T09:08:19.436Z',
#  '1970-02-12T02:44:40.538Z',
#  '1970-02-17T15:24:12.506Z',
#  '1978-12-18T21:09:52.734Z',
#  '1971-09-30T23:27:24.058Z',
#  '1950-11-04T21:33:50.131Z',
#  '1948-11-14T18:39:10.548Z',
#  '1959-04-19T17:19:03.007Z',
#  '1957-01-01T01:30:05.143Z',
#  '1987-09-28T03:07:19.065Z',
#  '1948-03-26T09:29:52.066Z',
#  '1962-07-12T19:19:38.503Z',
#  '1948-12-16T18:08:00.039Z',
#  '1984-12-01T10:58:46.657Z',
#  '1952-05-27T16:42:20.196Z',
#  '1953-04-14T17:43:28.078Z',
#  '1962-05-18T21:10:14.139Z',
#  '1954-10-14T23:20:31.120Z',
#  '1985-04-25T12:23:30.106Z',
# ...

# %%
profile_male
# Out:
# [{'gender': 'male',
#   'name': {'title': 'Mr', 'first': 'Alfredo', 'last': 'Cabrera'},
#   'location': {'street': {'number': 1602, 'name': 'Calle de Argumosa'},
#    'city': 'Ferrol',
#    'state': 'Melilla',
#    'country': 'Spain',
#    'postcode': 47827,
#    'coordinates': {'latitude': '37.6916', 'longitude': '94.3361'},
#    'timezone': {'offset': '+5:30',
#     'description': 'Bombay, Calcutta, Madras, New Delhi'}},
#   'email': 'alfredo.cabrera@example.com',
#   'login': {'uuid': 'f81d95cc-d31c-43ab-91c7-4211b254d6b9',
#    'username': 'brownmeercat122',
#    'password': 'natalie',
#    'salt': 'TLZQDW3V',
#    'md5': '98ebd8ee61d7cd90856138b53213267b',
#    'sha1': 'fe64f0f1d4b49283854a4c5291df8eb8311759e2',
#    'sha256': '93822f562adb97b48ba8764a70df2e98bcd90f87d2a66a65f148b2ffd350e9d3'},
#   'dob': {'date': '1996-03-04T19:59:11.209Z', 'age': 29},
#   'registered': {'date': '2018-08-16T17:36:38.561Z', 'age': 6},
#   'phone': '999-041-402',
#   'cell': '646-481-931',
# ...

# %%
male_full_name = []
for firstname in profile_male:
    x = firstname['name']['first']
    y = firstname['name']['last']
    z = x + ' ' + y
    male_full_name.append(z)

male_full_name
# Out:
# ['Alfredo Cabrera',
#  'Don Cox',
#  'Aubin Muller',
#  'Coşkun Yorulmaz',
#  'Jean-Philippe Leroux',
#  'Noah King',
#  'Wesley Romero',
#  'Ante Dreyer',
#  'Larry Chapman',
#  'Micheal Bennett',
#  'Storm Andersen',
#  'Raymond Osullivan',
#  'Adam Jørgensen',
#  'Sebastián Campos',
#  'Rasmus Wirkkala',
#  'Felipe Esteban',
#  'Necati Zeh',
#  'Wiresh Kropman',
#  'Dev Bansal',
#  'کوروش حیدری',
#  'Eeli Kurtti',
#  'Robertino Duijzer',
#  'Joseph Moolya',
#  'Todd Jackson',
#  'Manuel Cortes',
#  'Anton Mortensen',
#  'Todd Allen',
#  'سپهر زارعی',
#  'Önal Çatalbaş',
#  'Natércio Moraes',
#  'Anaim da Cunha',
#  'Efe Özkök',
#  'Bartolomeu Perestrelo Moraes',
#  'Adam Tremblay',
#  'David Jones',
#  'Estéban Schmitt',
#  'Nagraj Chavare',
#  'Burckhard Hau',
#  'Carlos León',
#  'Lucas Benavides',
#  'Valentino Fonseca',
#  'Nakul Taj',
#  'Alfred Petersen',
#  'Jessie Spencer',
#  'Eelis Anttila',
#  'Stanoje Anđelić',
#  'Logan Patel',
#  'Arttu Lahti',
#  'Oscar Peña',
# ...

# %% [markdown]
# #TO TRY AGAIN
#  if firstname['name'] == 'first':
#         male_firstname.append(firstname[name])
#     elif firstname['name'] == 'Last':
#         male_lastname.append(firstname[name])

# %%
femalebirth = []
for female in profile_female:
    value = female['dob']
    femalebirth.append(value)
femalebirth
# Out:
# [{'date': '1980-12-31T05:02:26.800Z', 'age': 44},
#  {'date': '1964-02-21T05:07:53.066Z', 'age': 61},
#  {'date': '1947-06-26T21:24:38.393Z', 'age': 77},
#  {'date': '1954-11-16T14:18:52.479Z', 'age': 70},
#  {'date': '1989-04-01T18:26:11.453Z', 'age': 35},
#  {'date': '1974-03-19T06:37:12.419Z', 'age': 51},
#  {'date': '1955-11-13T18:55:05.461Z', 'age': 69},
#  {'date': '1967-02-16T14:15:21.877Z', 'age': 58},
#  {'date': '1981-05-25T15:27:02.711Z', 'age': 43},
#  {'date': '1984-05-01T22:12:30.052Z', 'age': 40},
#  {'date': '1963-05-03T04:50:19.227Z', 'age': 61},
#  {'date': '1975-09-12T14:10:01.017Z', 'age': 49},
#  {'date': '1983-09-01T12:42:26.766Z', 'age': 41},
#  {'date': '1947-06-29T14:09:54.779Z', 'age': 77},
#  {'date': '1966-05-26T17:42:24.625Z', 'age': 58},
#  {'date': '1967-11-11T06:03:18.630Z', 'age': 57},
#  {'date': '1974-09-28T15:13:02.956Z', 'age': 50},
#  {'date': '1948-05-08T10:28:37.297Z', 'age': 76},
#  {'date': '1953-02-20T02:22:25.236Z', 'age': 72},
# ...

# %%
female_birth_date = []
for female in femalebirth:
    datevalue =  female['date']
    female_birth_date.append(datevalue)   
female_birth_date
# Out:
# ['1980-12-31T05:02:26.800Z',
#  '1964-02-21T05:07:53.066Z',
#  '1947-06-26T21:24:38.393Z',
#  '1954-11-16T14:18:52.479Z',
#  '1989-04-01T18:26:11.453Z',
#  '1974-03-19T06:37:12.419Z',
#  '1955-11-13T18:55:05.461Z',
#  '1967-02-16T14:15:21.877Z',
#  '1981-05-25T15:27:02.711Z',
#  '1984-05-01T22:12:30.052Z',
#  '1963-05-03T04:50:19.227Z',
#  '1975-09-12T14:10:01.017Z',
#  '1983-09-01T12:42:26.766Z',
#  '1947-06-29T14:09:54.779Z',
#  '1966-05-26T17:42:24.625Z',
#  '1967-11-11T06:03:18.630Z',
#  '1974-09-28T15:13:02.956Z',
#  '1948-05-08T10:28:37.297Z',
#  '1953-02-20T02:22:25.236Z',
#  '1947-04-17T09:58:00.562Z',
#  '1993-05-23T21:17:39.641Z',
#  '1948-08-03T16:03:34.152Z',
#  '1960-12-02T06:15:02.202Z',
#  '1986-04-07T13:48:42.959Z',
#  '1986-03-03T07:33:20.121Z',
#  '1984-11-07T00:08:58.941Z',
#  '1950-01-03T10:03:39.246Z',
#  '2001-05-07T12:03:35.828Z',
#  '1990-02-17T08:21:02.943Z',
#  '1987-01-03T11:32:52.165Z',
#  '1966-04-19T08:46:35.460Z',
#  '1982-07-02T21:31:14.662Z',
# ...

# %%
female_full_name = []                    
for firstname in profile_female:
    x = firstname['name']['first']
    y = firstname['name']['last']
    z = x + ' ' + y
    female_full_name.append(z)

female_full_name
# Out:
# ['Hanna Renaud',
#  'Alicia Fernández',
#  'Martha Valladares',
#  'Adriana Stornes',
#  'Carolina Huiberts',
#  'Danielle Sanders',
#  'Lyna Renaud',
#  'Caitlin Hall',
#  'Maëlia Lopez',
#  'Barbara King',
#  'Juliette Bouchard',
#  'Elizabeth Pearson',
#  'Sofiya Kmicikevich',
#  'Jos Mota',
#  'Zélia da Conceição',
#  'Saanvi Keshri',
#  'Tatolyuba Shchogoliv',
#  'Sophia Morris',
#  'Norma Bryant',
#  'Jadranka Tomić',
#  'Lada Pantić',
#  'Kerttu Leino',
#  'Sophie Tremblay',
#  'Lea Taylor',
#  'Kristin Davidson',
#  'Marie Rasmussen',
#  'Federica Lecomte',
#  'Concepción Manzanares',
#  'Vanessa Armstrong',
#  'Veera Niskanen',
#  'Stella Yohannes',
#  'Zahra Fossen',
#  'Oona Tuominen',
#  'Lily Li',
#  'Gervásia Gomes',
#  'Thea Kristensen',
#  'Sedef Özkara',
#  'Bernadette Roger',
#  'Valeria Tomić',
#  'Rachel Ward',
#  'Sophie Gomez',
#  'هستی کریمی',
#  'Alexis Evans',
#  'Elizabeth Harper',
#  'Begüm Tokatlıoğlu',
#  'Olivia Rojo',
#  'Pava Pavlovich',
# ...

# %%
female_full_name = []
for firstname in profile_female:
    x = firstname['name']['first']
    y = firstname['name']['last']
    z = x + ' ' + y
    female_full_name.append(z)

female_full_name
# Out:
# ['Hanna Renaud',
#  'Alicia Fernández',
#  'Martha Valladares',
#  'Adriana Stornes',
#  'Carolina Huiberts',
#  'Danielle Sanders',
#  'Lyna Renaud',
#  'Caitlin Hall',
#  'Maëlia Lopez',
#  'Barbara King',
#  'Juliette Bouchard',
#  'Elizabeth Pearson',
#  'Sofiya Kmicikevich',
#  'Jos Mota',
#  'Zélia da Conceição',
#  'Saanvi Keshri',
#  'Tatolyuba Shchogoliv',
#  'Sophia Morris',
#  'Norma Bryant',
#  'Jadranka Tomić',
#  'Lada Pantić',
#  'Kerttu Leino',
#  'Sophie Tremblay',
#  'Lea Taylor',
#  'Kristin Davidson',
#  'Marie Rasmussen',
#  'Federica Lecomte',
#  'Concepción Manzanares',
#  'Vanessa Armstrong',
#  'Veera Niskanen',
#  'Stella Yohannes',
#  'Zahra Fossen',
#  'Oona Tuominen',
#  'Lily Li',
#  'Gervásia Gomes',
#  'Thea Kristensen',
#  'Sedef Özkara',
#  'Bernadette Roger',
#  'Valeria Tomić',
#  'Rachel Ward',
#  'Sophie Gomez',
#  'هستی کریمی',
#  'Alexis Evans',
#  'Elizabeth Harper',
#  'Begüm Tokatlıoğlu',
#  'Olivia Rojo',
#  'Pava Pavlovich',
# ...
